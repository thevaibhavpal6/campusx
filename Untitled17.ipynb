# %% [markdown]
# <a href="https://colab.research.google.com/github/thevaibhavpal6/campusx/blob/main/Untitled17.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('helloworld')
# Out:
# helloworld
