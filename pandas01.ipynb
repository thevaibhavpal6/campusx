# %% [markdown]
# <a href="https://colab.research.google.com/github/thevaibhavpal6/campusx/blob/main/pandas01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
country=['India','pakistan','USA','Nepal','srilanka']

# %%
print(type(country))
# Out:
# <class 'list'>

# %%
pd.Series(country)
# Out:
# 0       India
# 1    pakistan
# 2         USA
# 3       Nepal
# 4    srilanka
# dtype: object

# %%
runs=[13,24,56,78,100]

# %%
runs
# Out:
# [13, 24, 56, 78, 100]

# %%
runs_ser= pd.Series(runs)

# %%
runs_ser
# Out:
# 0     13
# 1     24
# 2     56
# 3     78
# 4    100
# dtype: int64

# %%
marks=[67,57,89,100]

# %%
subjects=['maths','english','science','hindi']

# %%
pd.Series(marks,index=subjects)
# Out:
# maths       67
# english     57
# science     89
# hindi      100
# dtype: int64

# %%
marks_series=pd.Series(marks,index=subjects,name='nitish ke marks')

# %%
marks_series.name
# Out:
# 'nitish ke marks'

# %%
marks_series.size
# Out:
# 4

# %%
marks_series.dtype
# Out:
# dtype('int64')

# %%
marks_series
# Out:
# maths       67
# english     57
# science     89
# hindi      100
# Name: nitish ke marks, dtype: int64

# %%
marks_series.is_unique
# Out:
# True

# %%
runs_ser.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
subs = pd.read_csv('/content/subs.csv')

# %%
subs
# Out:
#      Subscribers gained
# 0                    48
# 1                    57
# 2                    40
# 3                    43
# 4                    44
# ..                  ...
# 360                 231
# 361                 226
# 362                 155
# 363                 144
# 364                 172
#
# [365 rows x 1 columns]

# %%
vk=pd.read_csv('/content/kohli_ipl.csv',index_col='match_no')

# %%
vk.index.count()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_5894/1260866238.py in <cell line: 0>()
# ----> 1 vk.index.count()
#
# AttributeError: 'Index' object has no attribute 'count'
